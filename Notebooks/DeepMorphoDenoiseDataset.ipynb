# %%
# %cd ..
# Out:
# /hdd/aouadt/these/projets/3d_segm

# %%
from importlib import reload

import numpy as np
import matplotlib.pyplot as plt

import deep_morpho.datasets.utils as du
import deep_morpho.datasets.generate_sticks_noised as gsn
import deep_morpho.datasets.sticks_noised_dataset as dsn


def reload_modules():
    for modl in [du, gsn, dsn]:
        reload(modl)

# %%
reload_modules()
X, Y = gsn.get_sticks_noised(size=(100, 100), n_shapes=16, noise_proba=0.1, p_invert=0, angles=[0, 10, 20, 30, 50, 120])

# %%
plt.subplot(121)
plt.imshow(X, cmap='gray')

plt.subplot(122)
plt.imshow(Y, cmap='gray')

# %%
reload_modules()
dataset = dsn.SticksNoisedGeneratorDataset(size=(50, 50), angles=[0, 90], n_shapes=15, widths_lim=(2, 2))

img, tar = dataset[0]

plt.subplot(121)
plt.imshow(img[0], cmap='gray')

plt.subplot(122)
plt.imshow(tar[0], cmap='gray')

# %%
tar2 = morpop(tar.numpy().transpose(1, 2, 0))
plt.subplot(121)
plt.imshow(img[0], cmap='gray')

plt.subplot(122)
plt.imshow(tar2, cmap='gray', vmin=0, vmax=1)

# %%
morpop = dataset.get_default_morp_operation()
morpop.vizualise(figsize=(15, 15))

# %%
reload_modules()
plt.imshow(du.get_rect(1, 10, 45), cmap='gray')
